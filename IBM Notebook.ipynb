# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Estefania Castro**
# <br>
# Data Scientist

# %% [markdown]
# *I am interested in data science because I love numbers, math & stats.*

# %% [markdown]
# ### My code is supposed to print 1+1

# %%
1+1
# Out:
# 2

# %% [markdown]
# ***

# %% [markdown]
# * One
# * Two
# * Three
